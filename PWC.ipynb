# %%
from utils import *

import geopandas as gpd
import osmnx as ox
import networkx as nx

# %%
import utils.helpers as h

print(h.__all__)
# Out:
# ['generate_graph', 'fill_holes_and_dissolve']

# %%
from utils.helpers import *

# %%
pol = generate_graph("Prince William County, Virginia, USA")

# %%
pol[0]
# Out:
# <POLYGON ((-77.716 38.841, -77.716 38.843, -77.705 38.843, -77.704 38.844, -...>
